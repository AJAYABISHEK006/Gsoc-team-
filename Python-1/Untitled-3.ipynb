# %%
string=input()
no_of_words=string.split()
print("Number of words: ",len(no_of_words))
print("First 20 characters: ",string[0:20])
a=string.lower()
print("Formatted paragraph: ",a.replace(" ","_"))
word=input()
b=a.count(word)
print(f"{word} appears {b} times")
# Out:
# Number of words:  8
# First 20 characters:  This is a Python pro
# Formatted paragraph:  this_is_a_python_program_for_our_exam
#  appears 38 times
