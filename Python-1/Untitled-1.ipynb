# %%
a=input("Enter the obatained marks: ")
if int(a)>=90:
    print("Grade A+")
elif 75 <= int(a) <= 89:
    print("Grade A")
elif 60 <= int(a) <= 74:
    print("Grade B")
elif 50 <= int(a) <= 59:
    print("Grade C")
else:
    print("Fail")
# Out:
# Grade B

# %%
n=int(input("Enter the number: "))
for i in range(1,11):
    print(f"{n} x {i} = {n*i}")
# Out:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30

# %%
student=(45,"Athmika",19,"Artificual Intelligence")
roll_no,name,age,department=student 

print(f"Name: {name}")
print(f"Age: {age}")
print(f"Roll No: {roll_no}")
print(f"Department: {department}")
# Out:
# Name: Athmika
# Age: 19
# Roll No: 45
# Department: Artificual Intelligence

# %%
students={}
for i in range(5):
    roll=int(input())
    name=input()
    age=int(input())
    students[roll]={'Name':name,'Age':age}
print("\nStudent Details:")
for roll,details in students.items():
    print(f"Roll: {roll},Name:{details['Name']}, Age: {details['Age']}")
roll_numbers=list(students.keys())
print("All Roll Numbers:",roll_numbers)
names=[details['Name']for details in students.values()]
print("All Names:", names)
roll_to_search = int(input())
if roll_to_search in students:
    print(f"Details - Roll:{roll_to_search},Name:{students [roll_to_search]['Name']},Age:{students[roll_to_search]['Age']}")
else:
    print("Roll number not found.")
# Out:
# Student Details:
# Roll: 23,Name:ajay, Age: 20
# Roll: 18,Name:20, Age: 9
# Roll: 9,Name:dha, Age: 29
# All Roll Numbers: [23, 18, 9]
# All Names: ['ajay', '20', 'dha']
# Roll number not found.
