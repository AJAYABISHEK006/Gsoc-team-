# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data = {
    "Date": pd.date_range(start = "2026-01-01" , periods = 10 , freq = "D"),
    "Sales": [100,120,115,140,150,145,170,180,175,200]
}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#         Date  Sales
# 0 2026-01-01    100
# 1 2026-01-02    120
# 2 2026-01-03    115
# 3 2026-01-04    140
# 4 2026-01-05    150
# 5 2026-01-06    145
# 6 2026-01-07    170
# 7 2026-01-08    180
# 8 2026-01-09    175
# 9 2026-01-10    200

# %%
plt.plot(df["Date"], df["Sales"])
plt.xlabel("Date")
plt.ylabel("Sales")
plt.title("Sales Over Time")
plt.xticks(rotation = 45)
plt.show()
