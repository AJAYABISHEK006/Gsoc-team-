# %%
import pandas as pd

# %%
sales = [100,120,130,150,170]

# %%
df = pd.DataFrame({
    "sales": sales
})

# %%
print(df)
# Out:
#    sales
# 0    100
# 1    120
# 2    130
# 3    150
# 4    170

# %%
df["navie_prediction"] = df["sales"].shift(1)

# %%
print(df)
# Out:
#    sales  navie_prediction
# 0    100               NaN
# 1    120             100.0
# 2    130             120.0
# 3    150             130.0
# 4    170             150.0
