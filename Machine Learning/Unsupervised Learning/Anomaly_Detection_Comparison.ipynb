# %%
import numpy as np
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM
from sklearn.neighbors import LocalOutlierFactor
from sklearn.covariance import  EllipticEnvelope
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
contamination = 5 / len(x)

# %%
iso = IsolationForest(
    contamination = contamination,
    random_state = 42
)

# %%
iso_pred = iso.fit_predict(x)

# %%
svm = OneClassSVM(
    kernel = "rbf",
    gamma = "auto",
    nu = contamination
)

# %%
svm_pred = svm.fit_predict(x_scaled)

# %%
lof = LocalOutlierFactor(
    n_neighbors = 20,
    contamination = contamination
)

# %%
lof_pred = lof.fit_predict(x)

# %%
ee = EllipticEnvelope(
    contamination = contamination,
    random_state = 42
)

# %%
ee_pred = ee.fit_predict(x)

# %%
print("Isolation Forest:",
      np.sum(iso_pred == -1), "anomalies")
print("One-Class-SVM:",
      np.sum(svm_pred == -1), "anomalies")
print("LOF:",
      np.sum(lof_pred == -1), "anomalies")
print("Elliptic Envelope:",
      np.sum(ee_pred == -1), "anomalies")
# Out:
# Isolation Forest: 5 anomalies
# One-Class-SVM: 8 anomalies
# LOF: 5 anomalies
# Elliptic Envelope: 5 anomalies

# %%
true_anomaly_indices = np.arange(50,55)

# %%
print("Isolation Forest:",
      np.sum(iso_pred[true_anomaly_indices] == -1),
      "of 5 detected")
print("One-Class SVM:",
      np.sum(svm_pred[true_anomaly_indices] == -1),
      "of 5 detected")
print("LOF:",
      np.sum(lof_pred[true_anomaly_indices] == -1),
      "of 5 detected")
print("Elliptic Envelope:",
      np.sum(ee_pred[true_anomaly_indices] == -1),
      "of 5 detected")
# Out:
# Isolation Forest: 5 of 5 detected
# One-Class SVM: 3 of 5 detected
# LOF: 5 of 5 detected
# Elliptic Envelope: 5 of 5 detected
